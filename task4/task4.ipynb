# %%
import turtle
import tkinter as tk

def apply_rules(axiom, rules, iterations):
    for _ in range(iterations):
        new_axiom = ""
        for character in axiom:
            new_axiom += rules.get(character, character)
        axiom = new_axiom
    return axiom

def draw_l_system(t, instructions, angle, distance):
    stack = []
    for cmd in instructions:
        if cmd == 'F':
            t.forward(distance)
        elif cmd == 'X':
            pass
        elif cmd == '+':
            t.right(angle)
        elif cmd == '-':
            t.left(angle)
        elif cmd == '[':
            stack.append((t.position(), t.heading()))
        elif cmd == ']':
            position, heading = stack.pop()
            t.penup()
            t.setposition(position)
            t.setheading(heading)
            t.pendown()

def on_generate_click():
    axiom = axiom_entry.get()
    rule_string = rule_entry.get()
    rules = {rule.split("->")[0].strip(): rule.split("->")[1].strip() for rule in rule_string.split(",")}
    
    iterations = int(iterations_entry.get())
    angle = int(angle_entry.get())
    distance = int(distance_entry.get())

    instructions = apply_rules(axiom, rules, iterations)
    t.clear()
    t.penup()
    t.setposition(0, 0)
    t.setheading(90)
    t.pendown()
    draw_l_system(t, instructions, angle, distance)

root = tk.Tk()
root.title("L-System Tree Generator")

canvas = turtle.ScrolledCanvas(root)
canvas.pack(fill=tk.BOTH, expand=True)
screen = turtle.TurtleScreen(canvas)
t = turtle.RawTurtle(screen)
t.speed(0)

tk.Label(root, text="Axiom:").pack()
axiom_entry = tk.Entry(root)
axiom_entry.pack()

tk.Label(root, text="Rules (e.g., X->F+[[X]-X]-F[-FX]+X, F->FF):").pack()
rule_entry = tk.Entry(root)
rule_entry.pack()

tk.Label(root, text="Iterations:").pack()
iterations_entry = tk.Entry(root)
iterations_entry.pack()

tk.Label(root, text="Angle:").pack()
angle_entry = tk.Entry(root)
angle_entry.pack()

tk.Label(root, text="Distance:").pack()
distance_entry = tk.Entry(root)
distance_entry.pack()

generate_button = tk.Button(root, text="Generate", command=on_generate_click)
generate_button.pack()

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/nix/store/9mp1h1bi1l6bd15bqwpd0mf57gyz1brd-python3-3.11.5/lib/python3.11/tkinter/__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "/tmp/nix-shell.U3YV3t/ipykernel_25994/1888352891.py", line 47, in on_generate_click
#     draw_l_system(t, instructions, angle, distance)
#   File "/tmp/nix-shell.U3YV3t/ipykernel_25994/1888352891.py", line 16, in draw_l_system
#     t.forward(distance)
#   File "/nix/store/9mp1h1bi1l6bd15bqwpd0mf57gyz1brd-python3-3.11.5/lib/python3.11/turtle.py", line 1638, in forward
#     self._go(distance)
#   File "/nix/store/9mp1h1bi1l6bd15bqwpd0mf57gyz1brd-python3-3.11.5/lib/python3.11/turtle.py", line 1606, in _go
#     self._goto(ende)
#   File "/nix/store/9mp1h1bi1l6bd15bqwpd0mf57gyz1brd-python3-3.11.5/lib/python3.11/turtle.py", line 3175, in _goto
#     screen._pointlist(self.currentLineItem),
# ...
